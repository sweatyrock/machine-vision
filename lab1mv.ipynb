# %%
import matplotlib.pyplot as plt
import matplotlib.image as pltimage
from PIL import Image

img = Image.open('C:\\Users\\User\\Desktop\\lab1\\6_26.jpg')
area = (900,240, 1240,600)
cropped_img = img.crop(area)
cropped_img.show() 
plt.subplot(121)
plt.imshow(cropped_img)
plt.show();

# %%
import matplotlib.pyplot as plt
import matplotlib.image as pltimage
from PIL import Image
 

img = Image.open('C:\\Users\\User\\Desktop\\lab1\\6_26.jpg')
r, g, b = img.split()
im1 = Image.merge("RGB", (r, g, b))
im2 = Image.merge("RGB", (r, b, g))
im3 = Image.merge("RGB", (g, b, r))
im4 = Image.merge("RGB", (g, r, b))
im5 = Image.merge("RGB", (b, g, r))
im6 = Image.merge("RGB", (b, r, g))

plt.subplot(231);
plt.imshow(im1);
plt.subplot(232);
plt.imshow(im2);
plt.subplot(233);
plt.imshow(im3);
plt.subplot(234);
plt.imshow(im4);
plt.subplot(235);
plt.imshow(im5);
plt.subplot(236);
plt.imshow(im6);
plt.show();

# %%
import matplotlib.pyplot as plt
import matplotlib.image as pltimage
from PIL import Image
 

img = Image.open('C:\\Users\\User\\Desktop\\lab1\\6_26.jpg')
box = (900, 240, 1240 , 600)
box2 = ( 700,40, 1040,400)
region = img.crop(box)
img.paste(region, box2)
img.save("output.png")
 img2 = Image.open('.\\output.png')
img2.show()
# Out:
#   File "<ipython-input-58-a4ed78880119>", line 12
#     img2 = Image.open('.\\output.png')
#     ^
# IndentationError: unexpected indent

# %%
import matplotlib.pyplot as plt
import matplotlib.image as pltimage
from PIL import Image
 

img = Image.open('C:\\Users\\User\\Desktop\\lab1\\6_26.jpg')
box = (900,240, 1240,600)
region = img.crop(box)
box2 = ( 700,40, 1040,400)
img.paste(region, box2)
img.save('C:\\Users\\User\\Desktop\\lab1\\output.png')
